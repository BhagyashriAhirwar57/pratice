# %% [markdown]
# <a href="https://colab.research.google.com/github/BhagyashriAhirwar57/pratice/blob/main/Crawler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import json 

from datetime import date, timedelta

# %%
#Global variable
questions_list = []

#query from user 
#sample query to take keyword from user
keyword=  input("Enter a keyword: ")
keyword1=keyword

#search keyword on quora
#keyword = keyword + "site:quora.com site:reddit.com"
#string concatenation

site_list = ["quora.com"]
for site in site_list:
  keyword = keyword + " site:"+site
  print(keyword)
  

  #search on google 
  google_url = "https://customsearch.googleapis.com/customsearch/v1/?key=AIzaSyBxd13dFyCgw14yRVS2hIvCQSfBG8XfA-w&cx=310e922e6267d450d"
  google_url = google_url + "&q=" + keyword
  #print("Google URL: " + google_url)

  #send network request to google
  response = requests.get(google_url)
  #print("Response: " + str(response.text))

  #converting response to json file
  json_response = json.loads(response.text)
  #search_time = json_response["searchInformation"]["searchTime"]
  #print("Search time taken is ", search_time)

  total_results = int(json_response["searchInformation"]["totalResults"])
  #print("Total rsults are ", total_results)

  #Get the start index of first page
  #next_index = json_response["queries"]["nextPage"][0]["startIndex"]

  #Loop through all the responses from google
  total_pages = round(total_results/10)
  
  try:
    #loop through responses
      for item in json_response["items"]:
        title =item["title"]
        title = title.replace(" - Quora", "")
        questions_list.append(title)
        print(title)
     

  except Exception as e:
    #print or pass this
    pass
    #print("Exception", e)



  #reset the keyword
  keyword = keyword1

#questions_list
questions_dict = {"Questions": questions_list}
df = pd.DataFrame(data=questions_dict)

df
# Out:
# Enter a keyword: Python interview questions
# Python interview questions site:quora.com
# What are good Python interview questions?
# How to prepare for a Python interview for experienced developers ...
# What are the interview questions asked for Python QA automation ...
# What are some interesting intermediate level Python interview ...
# What are the Python interview questions generally asked to a ...
# What are some trickiest questions asked in a Python interview ...
# How to crack Python interview questions
# What are HCl interview questions for python experienced ...
# What are some must know Python-specific interview questions and ...
# What are your views on using Python for coding interviews?
#                                            Questions
# 0          What are good Python interview questions?
# 1  How to prepare for a Python interview for expe...
# 2  What are the interview questions asked for Pyt...
# 3  What are some interesting intermediate level P...
# 4  What are the Python interview questions genera...
# 5  What are some trickiest questions asked in a P...
# 6            How to crack Python interview questions
# 7  What are HCl interview questions for python ex...
# 8  What are some must know Python-specific interv...
# 9  What are your views on using Python for coding...
